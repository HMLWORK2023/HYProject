# %% [markdown]
# # BISI CST2101 Project - Diabetes Analysis
#
# ---------------
# ## Context
# ---------------
#
# Diabetes is one of the most frequent diseases worldwide and the number of diabetic patients are growing over the years. The main cause of diabetes remains unknown, yet scientists believe that both genetic factors and environmental lifestyle play a major role in diabetes.
#
# A few years ago research was done on a tribe in America which is called the Pima tribe (also known as the Pima Indians). In this tribe, it was found that the ladies are prone to diabetes very early. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients were females at least 21 years old of Pima Indian heritage.
#
# -----------------
# ## Objective
# -----------------
#
# Here, we are analyzing different aspects of Diabetes in the Pima tribe by doing Exploratory Data Analysis.
#
# -------------------------
# ## Data Dictionary
# -------------------------
#
# The dataset has the following information:
#
# * Pregnancies: Number of times pregnant
# * Glucose: Plasma glucose concentration over 2 hours in an oral glucose tolerance test
# * BloodPressure: Diastolic blood pressure (mm Hg)
# * SkinThickness: Triceps skin fold thickness (mm)
# * Insulin: 2-Hour serum insulin (mu U/ml)
# * BMI: Body mass index (weight in kg/(height in m)^2)
# * DiabetesPedigreeFunction: A function which scores likelihood of diabetes based on family history.
# * Age: Age in years
# * Outcome : Class variable (0: person is not diabetic or 1: person is diabetic)

# %% [markdown]
# ### Q1: Import the necessary libraries and briefly explain the use of each library (1 Mark)

# %%
# remove _____ & write the appropriate library name

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# You don't have to explain about these libraries below
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ansnwer 1:  Import the below librarys:
#
#
# NumPy, the command: import numpy as np:
# NumPy is a common used powerful library, in order to run numerical calculatio in Python scripts. It can handle arryes and matrices,  and math function, it is also foundations of other Pythong libraries.
#
#
# Pandas, the command: import pandas as pd:
# Pandas can be used to run Series and DataFrame,  for structured raw data.  It can handle data cleanning, EDA, and transformation.
#
# Seaborn: the command:  import seaborn as sns
#
# Seaborn provides visualizaiton funcation for statisticial, it is based on the pacakge of Matplolib.  It is good at draw graphics for statistical usage.
#
# Matplotlib: import matplotlib.pyplot as plt
# It is use to draw 2 degree plottting for Python.   Its part pyplot, is a module,  can draw inteac plots.

# %% [markdown]
# ### Q2: Read the given dataset (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima = pd.read_csv("diabetes.csv")

# %% [markdown]
# ### Q3. Show the last 5 records of the dataset (1 Mark)

# %%
#remove ______ and write the appropriate number in the function

pima.tail(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 995            2      173             79             32      474  35.504233
# 996           13      132             70             30      111  35.271769
# 997            3      132             87             44      156  34.794755
# 998            0      140              0              0        0  41.926693
# 999            4       93             59             35       93  45.914499
#
#      DiabetesPedigreeFunction  Age  Outcome
# 995                  0.402867   21        1
# 996                  0.168845   42        1
# 997                  0.765003   29        1
# 998                  0.209833   28        1
# 999                  0.737636   29        1

# %% [markdown]
# ### Q4. Show the first 5 records of the dataset (1 Mark)

# %%
#remove _____ & write the appropriate function name and the number of rows to get in the output

pima.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ### Q5. Find the dimension of the `pima` dataframe. What do you understand by the dimension of the dataset? (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima.shape
# Out:
# (1000, 9)

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Answer 5:
#
# (1000, 9)
#
# run pima.shape to show the dimenstion of the dataframe, it return rows' amount is 1000, and the columns' amount is 9
#
# Rows's amount is the total number of rows from the dataframe, every row is unque from other row.  Each row can be regards as on observation.
#
# Columns's amount is the total number of the all columns of the dataframe, each column represent a feature of the dataframe.  Such as BMI, Bloodpressure, etc.

# %% [markdown]
# ### Q6. Find the size of the `pima` dataframe. (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima.size
# Out:
# 9000

# %% [markdown]
# #### Write your Answer here:
# Ans 6:
# 9000

# %% [raw]
# Ans 6:
# 9000

# %% [markdown]
# ### Q7. Display the data types of all the variables in the data set? (1 Mark)

# %%
#remove _____ & write the appropriate function name

pima.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# ### Q8. Are there any missing values in the `pima` dataframe?  Which variables have missing values? (1 Mark)

# %%
#remove _____ & write the appropriate function name

#pima.______().values.any()


#Below is my solution:
#***********************************************

pima.isnull().any()
# Out:
# Pregnancies                 False
# Glucose                     False
# BloodPressure               False
# SkinThickness               False
# Insulin                     False
# BMI                         False
# DiabetesPedigreeFunction    False
# Age                         False
# Outcome                     False
# dtype: bool

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Answer: none of the variables has missing value.
#
# Or, we can use pima.isnull().sum() to calculete the number of the missing values for each varibales

# %% [markdown]
# ### Q9. Find the summary statistics for all variables except for  `'Outcome'` variable? Choose any one column/variable and explain all the statistical measures. (2 Marks)

# %%
#remove _____ & write the appropriate function name

#pima.iloc[:,__]._______()

#Below is my solution:
#***********************************************

pima.iloc[:,:-1].describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness      Insulin  \
# count  1000.000000  1000.00000    1000.000000    1000.000000  1000.000000
# mean      4.051000   125.21600      69.072000      20.755000    83.086000
# std       3.325576    32.27772      20.465328      16.008599   117.255326
# min       0.000000     0.00000       0.000000       0.000000     0.000000
# 25%       1.000000   102.00000      64.000000       0.000000     0.000000
# 50%       3.000000   122.00000      72.000000      24.000000    23.000000
# 75%       6.000000   146.00000      80.000000      33.000000   133.500000
# max      17.000000   199.00000     122.000000      99.000000   846.000000
#
#                BMI  DiabetesPedigreeFunction          Age
# count  1000.000000               1000.000000  1000.000000
# mean     32.664772                  0.494090    33.830000
# std       7.563614                  0.322158    11.268189
# min       0.000000                  0.078000    21.000000
# ...

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Answer 9:
#
#
# We can choose any of the column, such as 'Glucose', to review the measure from statistical view.
#
# First measure, "Count", it represent the total number of the column which value is not null
# Second measure, "mean": it repsent the average of the column's all value, divied by the "count".
# Third "std", it means standard deviation, it is calculaton of standard deviation of the column
# min: it gives the min value of the column.
# 25% (q1), it is the lowest 25th (quartile) of the column.
# 50% : This give the middle of the column
# 75%: It gives the 75th of the value of the column.
# max: It gives the maximum value of the column.

# %% [markdown]
# ### Q10. Plot the distribution plot for the variable `'BloodPressure'`. Write your observations from the plot. (2 Marks)

# %%
#remove _____ & write the appropriate library name

#sns._____(pima['BloodPressure'], kind='kde')
#plt.show()


#Below is my solution:
sns.histplot(pima['BloodPressure'], kde=True)
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Answer 10:  After create the plt graph, we can check the details of it:
#
# 1,The general distribution, which is skewed to right direciton
# 2,THe peak of the distribution is around 72-74 years old, peak amount is over 140
# 3, Outlifer exist in the earlier years old, after new born.  It is correct for the new born baby.

# %% [markdown]
# ### Q11. What is the `'BMI'` for the person having the highest `'Glucose'`? (1 Mark)

# %%
#remove _____ & write the appropriate function name

#pima[pima['Glucose']==pima['Glucose']._____()]['BMI']


#Below is my solution:
pima[pima['Glucose'] == pima['Glucose'].idxmax()]['BMI']

#Add the below statements to output the BMI of the person who has the highest 'Glucose'
index_of_the_highest_glucose = pima['Glucose'].idxmax()
value_of_bmi_of_the_highest_glucose = pima.at[index_of_the_highest_glucose, 'BMI']
value_of_bmi_of_the_highest_glucose
# Out:
# 42.9

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 11: For the person who has highest Glucose, the person's BMI is 42.9

# %% [markdown]
# ### Q12.
# #### 12.1 What is the mean of the variable `'BMI'`?
# #### 12.2 What is the median of the variable `'BMI'`?
# #### 12.3 What is the mode of the variable `'BMI'`?
# #### 12.4 Are the three measures of central tendency equal?
#
# ### (2 Marks)

# %%
#remove _____ & write the appropriate function name

#m1 = pima['BMI'].____()  #Mean
#print(m1)
#m2 = pima['BMI'].____()  #Median
#print(m2)
#m3 = pima['BMI'].____()[0]  #Mode
#print(m3)


#Below is my solution:
#################################
m1 = pima['BMI'].mean()
m2 = pima['BMI'].median()
m3 = pima['BMI'].mode()[0] 

print("The Mean of BMI:", m1)
print("The Median of BMI:", m2)
print("The Mode of BMI:", m3)
# Out:
# The Mean of BMI: 32.664772391408796
# The Median of BMI: 32.8
# The Mode of BMI: 32.0

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Answer of Question 12
# Q12.
# 12.1 What is the mean of the variable 'BMI'?  The Mean of BMI: 32.664772391408796
# 12.2 What is the median of the variable 'BMI'?   The Median of BMI: 32.8
# 12.3 What is the mode of the variable 'BMI'?     The Mode of BMI: 32.0
# 12.4 Are the three measures of central tendency equal?  No

# %% [markdown]
# ### Q13. How many women's `'Glucose'` level is above the mean level of `'Glucose'`? (1 Mark)

# %%
#remove _____ & write the appropriate function name

#pima[pima['Glucose']>pima['Glucose']._____()].shape[0]

#Below is my solution:
#################################

pima[pima['Glucose'] > pima['Glucose'].mean()].shape[0]
# Out:
# 449

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 13:Number of women with Glucose level above the mean: 449

# %% [markdown]
# ### Q14. Create the pairplot for variables `'Glucose'`, `'SkinThickness'` and `'DiabetesPedigreeFunction'`. Write you observations from the plot. (2 Marks)

# %%
#remove _____ & write the appropriate function and argument names

#sns.______(data=pima, ___=['Glucose', 'SkinThickness', 'DiabetesPedigreeFunction'], hue='Outcome')
#plt.show()

#Below is my solution:
#################################


sns.pairplot(data=pima, vars=['Glucose', 'SkinThickness', 'DiabetesPedigreeFunction'], hue='Outcome')
plt.show()
# Out:
# C:\Users\hy202\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Answer 14:
# After complete the pairplot graph, let us check it:
#
#
# Check for outlier,
# There is particular outlier for skinThickness
# There is particular outlier for Glocose
#
#
# Check Correlation:
# For the 'Glucose' and 'DiabetesPedigreeFunction', there is correlation between these two items.

# %% [markdown]
# ### Q15. Plot the scatterplot between `'Glucose'` and `'Insulin'`. Write your observations from the plot. (1 Mark)

# %%
#remove _____ & write the appropriate function name

#sns._______(x='Glucose',y='Insulin',data=___)
#plt.show(
    
#Below is my solution:
#################################

sns.scatterplot(x='Glucose', y='Insulin', data=pima)
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Answer 15:
#
# After complete the scatterplot, let us check it:
#
# Correlation Direction:
#
# The value "Glucose" and "Insulin" has some strong correlation.  Let us try to verify it in later section.
#
# Check Outliers:
# There is particular outliers.

# %% [markdown]
# ### Q16. Plot the boxplot for the 'Age' variable. Are there outliers? (1 Mark)

# %%
#remove _____ & write the appropriate function and column name 

#plt.______(pima['____'])

#plt.title('Boxplot of Age')
#plt.ylabel('Age')
#plt.show()


#Below is my solution:
#################################


plt.boxplot(pima['Age'])
plt.title('Boxplot of Age')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Answer 16:
#
# From the Boxlot, we can find some outliers, which is part of value of "Age".  We can obesever these outliers is beyoid the box's whiskers.

# %% [markdown]
# ### Q17. Find and visualize the the correlation matrix. Write your observations from the plot. (1 Mark)

# %%
#remove _____ & write the appropriate function name and run the code

#corr_matrix = pima.iloc[:,0:8].______
#corr_matrix

#Below is my solution:
#################################


corr_matrix = pima.iloc[:, 0:8].corr()
corr_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.112930       0.127463      -0.080033
# Glucose                      0.112930  1.000000       0.134993       0.050656
# BloodPressure                0.127463  0.134993       1.000000       0.249063
# SkinThickness               -0.080033  0.050656       0.249063       1.000000
# Insulin                     -0.064909  0.334175       0.117369       0.472663
# BMI                          0.012920  0.222138       0.247275       0.387055
# DiabetesPedigreeFunction    -0.025452  0.127004       0.059303       0.214026
# Age                          0.548665  0.255567       0.240416      -0.121236
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.064909  0.012920                 -0.025452
# Glucose                   0.334175  0.222138                  0.127004
# ...

# %%
#remove _____ & write the appropriate function name

#plt.figure(figsize=(8,8))
#sns._______(corr_matrix, annot = True)

# display the plot
#plt.show()

#Below is my solution:
#################################

plt.figure(figsize=(8,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Answer 17:
#
# After output the matrix (1) and heatmap(2), let us watch both of them, and match the observation from each of them:
#
#
# Firstly, let us check the correlation relation, we can see the 'Age' and 'Pregnancies' has strong correlation, which has a coefficient of '0.55'.
#
# "SkinThickness" and "Insulin" has a correlation with coefficient of 0.472663
#
# "SkinThickness" and "BMI" has a correlation with coefficientg of 0.387055
#
# "Glucose" and "Insulin" has a correlation with coefficient of 0.334175
#
# Then, we check the correlation between "Age" and "Bloodpressure", there is moderate correlation, with e coefficient of "0.26", similarly, and there is moderate correlation between "Age" and "Glucose", with coefficient of "0.24"
#
#
# Also, we can find the negative correlation, for example, The correlation between "Age" and "SkinThickness" is -0.121236, which means, the higher of "age", related to lower of "SkinThickness"

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Q18. Split and scale the data (2 Mark)

# %%
# Split the data into dependent and independent variables
# remove _____ & write the appropriate function variable name
#y = pima._____
#x = pima.drop('____', axis = 1)

#Below is my solution:
#################################

y = pima['Outcome']
x = pima.drop('Outcome', axis=1)

# %%
# Using StandarScaler scale the data
# remove _____ & write the appropriate function function name

#from sklearn.preprocessing import _______
#scaler = _______()
#X = scaler.fit_transform(x)

#Below is my solution:
#################################


from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(x)

# %%
# Splitting the data into train and test. Use test size as 15%
# remove _____ & complete the code

#from sklearn.model_selection import ______
#x_train, x_test, y_train, y_test = train_test_split(__, __, test_size = ____, stratify=y,  random_state = 45)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.15, stratify=y, random_state=45)

# %% [markdown]
# ### Q19. Train a Logistic Regression Model. What is the Accuracy and how many True Positives and True Negatives did you get? (3 Marks)

# %%
# remove _____ & complete the code

# import the model
#from sklearn.linear_model import LogisticRegression

# Instantiate the model
#lr = LogisticRegression()

# fit the model on the train set
#m = lr.___(x_train, ____)

# Predict on x_test
#y_pred = m.predict(____)

# Evaluate the model
#print('Accuracy of Logistic Regression model on the train set: {:.2f}'.format(m.score(x_train, y_train)))
#print('Accuracy of the Logictic Regression model on the test set: {:.2f}'.format(m.score(x_test, y_test)))

#from sklearn.metrics import confusion_matrix
#confusion_matrix(y_test, y_pred)


#Below is my solution:
#################################


from sklearn.linear_model import LogisticRegression

# Instantiate the model
lr = LogisticRegression(max_iter=1000)

# Fit the model on the training set
m = lr.fit(x_train, y_train)

# Predict on x_test
y_pred_lr = m.predict(x_test)

# Evaluate the model
accuracy_train_lr = m.score(x_train, y_train)
accuracy_test_lr = m.score(x_test, y_test)

print('Accuracy of Logistic Regression model on the train set: {:.2f}'.format(accuracy_train_lr))
print('Accuracy of Logistic Regression model on the test set: {:.2f}'.format(accuracy_test_lr))


from sklearn.metrics import confusion_matrix
conf_matrix_lr = confusion_matrix(y_test, y_pred_lr)
#print('Confusion Matrix:')
#print(conf_matrix_lr)

conf_matrix_lr
# Out:
# Accuracy of Logistic Regression model on the train set: 0.76
# Accuracy of Logistic Regression model on the test set: 0.75
# array([[60, 15],
#        [22, 53]], dtype=int64)

# %% [markdown]
# #### Write your Answer here:
#
# Accuracy of Logistic Regression model on the train set: 0.76
# Accuracy of Logistic Regression model on the test set: 0.75

# %% [markdown]
# ### Q20. Train a Random Forest Model. What is the Accuracy and how many True Positives and True Negatives did you get? (3 Marks)

# %%
#remove _____ & complete the code

# Import the Model
#from sklearn.ensemble import RandomForestClassifier

# Instantiate the model. 
#rf = RandomForestClassifier(n_estimators=301, max_depth=3)

# fit the model on the train set
#m2 = rf.___(x_train, y_train)

# Predict on x_test
#y_pred2 = m2._____(x_test)

# Evaluate the Model
#print('Accuracy of Random Forest model on the train set: {:.2f}'.format(m2.score(x_train, y_train)))
#print('Accuracy of Random Forest model on the test set: {:.2f}'.format(m2.score(x_test, y_test)))
#confusion_matrix(y_test, y_pred2)

#The below is my solution:
#***********************************************

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

# Instantiate the model
rf = RandomForestClassifier(n_estimators=301, max_depth=3)

# Fit the model on the training set
model_rf = rf.fit(x_train, y_train)

# Predict on x_test
y_pred_rf = model_rf.predict(x_test)

# Evaluate the model
#accuracy_train_rf = model_rf.score(x_train, y_train)
#accuracy_test_rf = model_rf.score(x_test, y_test)

print('Accuracy of Random Forest model on the train set: {:.2f}'.format(model_rf.score(x_train, y_train)))
print('Accuracy of Random Forest model on the test set: {:.2f}'.format(model_rf.score(x_test, y_test)))

# Confusion matrix

#print('Confusion Matrix:')
#print(conf_matrix_rf)
conf_matrix_rf = confusion_matrix(y_test, y_pred_rf)
conf_matrix_rf
# Out:
# Accuracy of Random Forest model on the train set: 0.82
# Accuracy of Random Forest model on the test set: 0.77
# array([[55, 20],
#        [14, 61]], dtype=int64)

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 20:
#
# Accuracy of Random Forest model on the train set: 0.82
# Accuracy of Random Forest model on the test set: 0.77

# %% [markdown]
# ### Q21. Which model performed better? (1 Mark)

# %% [markdown]
# #### Write your Answer here:

# %% [markdown]
# Ans 21:From the above results and observation on the dataset, Random Forest Model performed better, because its Accuracy on train set and test set is higher than that of  Logistic Regression Model
